# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from memformers.models.membart import MemBartForConditionalGeneration

import os
import nltk
import pandas as pd
import torch
import numpy as np
from jinja2 import Template
import pickle
from collections import defaultdict

from fuzzywuzzy import fuzz

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from util_research import *

import matplotlib.pyplot as plt
from math import log

import pdb

# %%
path_andersen = "/kuacc/users/bozyurt20/hpc_run/ChildrenStories/Andersen"
path_fanny = "/kuacc/users/bozyurt20/hpc_run/ChildrenStories/Fanny Fern"
path_annotations = "/kuacc/users/bozyurt20/hpc_run/ChildrenStories/Annotations"

dir_list_andersen = os.listdir(path_andersen)
dir_list_fanny = os.listdir(path_fanny)
dir_list_annotations = os.listdir(path_annotations)

# %%
all_annotations = {}

for item in dir_list_annotations:
    
    f = open(os.path.join(path_annotations, item), 'r')
    annotations = pd.read_csv(f, sep="\t")
    annotations = annotations.values
    f.close()
    
    all_annotations[item] = annotations

# %%
story_info = {}
for story in all_annotations:
    story_info[story] = {}
    for character_list in all_annotations[story]:
        character_name = character_list[1]
        story_info[story].setdefault(character_name, [])
        story_info[story][character_name].append((character_list[0], character_list[2], character_list[3]))
        story_info[story][character_name].sort(key=lambda x: x[0])

# %%
all_annotations["Andersen_story3.txt"]
# Out:
# array([[178, 'the prince', 'all over the world', 'singular'],
#        [453, 'the prince',
#         "his palace/the prince's palace/the palace/at home/home/his home/his castle/the castle",
#         'singular'],
#        [797, 'the king',
#         'the palace/outside/out/the castle/in his castle', 'singular'],
#        [850, 'the princess',
#         'the palace/the castle/outside the door/outside/out', 'singular'],
#        [1079, 'the queen', 'the palace/the castle/at home', 'singular'],
#        [1173, 'the queen', 'the bedroom/the palace/the castle/at home',
#         'singular']], dtype=object)

# %%
story_info["Andersen_story3.txt"]
# Out:
# {'the prince': [(178, 'all over the world', 'singular'),
#   (453,
#    "his palace/the prince's palace/the palace/at home/home/his home/his castle/the castle",
#    'singular')],
#  'the king': [(797,
#    'the palace/outside/out/the castle/in his castle',
#    'singular')],
#  'the princess': [(850,
#    'the palace/the castle/outside the door/outside/out',
#    'singular')],
#  'the queen': [(1079, 'the palace/the castle/at home', 'singular'),
#   (1173, 'the bedroom/the palace/the castle/at home', 'singular')]}

# %%
class MemoryEnhanced():
    def __init__(self, model, tokenizer, device):
        self.model = model
        self.tokenizer = tokenizer
        self.model = self.model.to(device)
        self.device = device
        
class MemoryEnhancedResults():
    def __init__(self, prompt, model_out, gold_locations, character, k, story_no, query_point, exact_match, fuzzy_match):
        self.prompt = prompt
        self.model_out = model_out
        self.gold_locations = gold_locations
        self.character = character
        self.k = k
        self.story_no = story_no
        self.query_point = query_point
        self.exact_match = exact_match
        self.fuzzy_match = fuzzy_match

# %%
def get_memory_states(memory_enhanced_instance, all_prompt_drafts):
    
    model = memory_enhanced_instance.model
    tokenizer = memory_enhanced_instance.tokenizer
    device = memory_enhanced_instance.device
    
    all_memory_states = []
    memory_states = model.construct_memory(batch_size=1)
    all_memory_states.append(memory_states)
    
    for prompt_draft in all_prompt_drafts:
    
        input_ids = torch.LongTensor([tokenizer.encode(prompt_draft)])
        input_ids = input_ids.to(device)
        encoder_outputs = model.model.encoder(input_ids=input_ids, memory_states=memory_states, attention_mask=None)
        memory_states = encoder_outputs.memory_states
        all_memory_states.append(memory_states)
        
    return all_memory_states

# %%
def predictor(memory_enhanced_instance, write_in_file=False, out_path_prefix="Text_injection_MEMBART_"):

    model = memory_enhanced_instance.model
    tokenizer = memory_enhanced_instance.tokenizer
    device = memory_enhanced_instance.device
    all_result_objects = defaultdict(list)

    version = 0

    for item in dir_list_annotations:

        print(item)

        story_no = item[len("Andersen_story"):-len(".txt")]

        f = open(os.path.join(path_andersen, item), 'r') 
        story = f.read()
        f.close()

        characters = story_info[item].keys()
        story = remove_new_lines(story)

        big_prompt = "Story:\n" + story
        big_prompt_tokens = tokenizer.encode(big_prompt)
        toks_per_segment = 512
        no_segments = len(big_prompt_tokens) // toks_per_segment

        all_tokens = [ big_prompt_tokens[512*i : 512*(i+1)] for i in range(no_segments) ]

        all_tokens.append(big_prompt_tokens[512*(no_segments): ])

        all_prompt_drafts = [ tokenizer.decode(x, skip_special_tokens=True) for x in all_tokens ]
        
        all_memory_states = get_memory_states(memory_enhanced_instance, all_prompt_drafts)

        x = 0
        story_lens = []
        for prompt_draft in all_prompt_drafts:
            if prompt_draft[:len("Story:\n")] == "Story:\n":
                x += len(prompt_draft) - len("Story:\n")
            else:
                x += len(prompt_draft)
            story_lens.append(x)

        for i, prompt_draft in enumerate(all_prompt_drafts):
            
            print(i)

            for character in characters:
                
                print(character)

                tuples = story_info[item][character]

                grammatical_number = tuples[0][2]
                if i != 0:
                    pos = story_lens[i-1]
                else:
                    pos = 0

                prompt, pos_last = create_membart_prompt(tokenizer, version, prompt_draft, character, grammatical_number, max_no_tokens=512)

                pos += pos_last

                check = False

                for num_tupl, tupl in enumerate(tuples):

                    if pos < tupl[0]:
                        break
                    gold_location = tupl[1]
                    check = True

                if check:
                    input_ids = torch.LongTensor([tokenizer.encode(prompt)])
                    encoder_outputs = model.model.encoder(input_ids=input_ids, memory_states=all_memory_states[i], attention_mask=None)
                    #memory_states = encoder_outputs.memory_states
                    
                    outputs = model.generate(
                        encoder_outputs=encoder_outputs,
                        decoder_start_token_id=tokenizer.bos_token_id,
                        max_length=64,
                        num_beams=1,
                        do_sample=False,
                        return_dict_in_generate=True,
                    )

                    out = tokenizer.decode(outputs.sequences[0])
                    match1, match2 = exactly_or_fuzzily_matched(out, gold_locations)
                    result_object =  MemoryEnhancedResults(prompt, out, gold_locations, character, version, story_no, pos, match1, match2)
                    all_result_objects[version].append(result_object)                 

    return all_result_objects

# %%
model = MemBartForConditionalGeneration.from_pretrained("qywu/membart-large")
tokenizer = AutoTokenizer.from_pretrained("facebook/bart-large")
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

memory_enhanced_instance = MemoryEnhanced(model, tokenizer, device)

# %%
all_result_objects = predictor(memory_enhanced_instance, write_in_file=False, out_path_prefix="Text_injection_MEMBART_")
# Out:
# Andersen_story11.txt
# here
# here
# here2
# here2
# here2
# here2
# here2

# %%
def accuracy_calculator(all_result_objects):
    
    exact_accuracies = defaultdict(list)
    fuzzy_accuracies = defaultdict(list)
    exact_averages = defaultdict(list)
    fuzzy_averages = defaultdict(list)

    for k in all_result_objects:
        for result_object in all_result_objects[k]:
            """prompt = result_object.prompt
            out = result_object.out
            story_no = result_object.story_no
            k = result_object.k"""
            match1 = result_object.match1
            match2 = result_object.match2
            if match1 == "Yes":
                exact_accuracies[k].append(1)
            else:
                exact_accuracies[k].append(0)
            if match2 == "Yes":
                fuzzy_accuracies[k].append(1)
            else:
                fuzzy_accuracies[k].append(0)
            
        exact_averages[k] = np.mean(np.array(exact_accuracies[k]))
        fuzzy_averages[k] = np.mean(np.array(fuzzy_accuracies[k]))
        
    best_exact_k = np.array(list(exact_averages.values())).argmax() + 1
    best_fuzzy_k = np.array(list(exact_averages.values())).argmax() + 1
    
    return exact_averages, fuzzy_averages, best_exact_k, best_fuzzy_k

# %%
exact_averages, fuzzy_averages, best_exact_k, best_fuzzy_k = accuracy_calculator(all_result_objects)

# %%
x = 1 
y = 2
breakpoint()
z = 4

# %%
version = 0
all_result_objects = {}
all_result_objects[version] = []

for item in dir_list_annotations:

    print(item)

    story_no = item[len("Andersen_story"):-len(".txt")]

    f = open(os.path.join(path_andersen, item), 'r') 
    story = f.read()
    f.close()

    characters = story_info[item].keys()
    story = remove_new_lines(story)

    big_prompt = "Story:\n" + story
    big_prompt_tokens = tokenizer.encode(big_prompt)
    toks_per_segment = 512
    no_segments = len(big_prompt_tokens) // toks_per_segment

    all_tokens = [ big_prompt_tokens[512*i : 512*(i+1)] for i in range(no_segments) ]

    all_tokens.append(big_prompt_tokens[512*(no_segments): ])

    all_prompt_drafts = [ tokenizer.decode(x, skip_special_tokens=True) for x in all_tokens ]

    all_memory_states = get_memory_states(memory_enhanced_instance, all_prompt_drafts)
    
    x = 0
    story_lens = []
    for prompt_draft in all_prompt_drafts:
        if prompt_draft[:len("Story:\n")] == "Story:\n":
            x += len(prompt_draft) - len("Story:\n")
        else:
            x += len(prompt_draft)
        story_lens.append(x)

    for i, prompt_draft in enumerate(all_prompt_drafts):

        print(i)

        for character in characters:

            print(character)

            tuples = story_info[item][character]

            grammatical_number = tuples[0][2]
            if i != 0:
                pos = story_lens[i-1]
            else:
                pos = 0
                
            print(pos)

            prompt, pos_last = create_membart_prompt(tokenizer, version, prompt_draft, character, grammatical_number, max_no_tokens=512)

            pos += pos_last
            
            print(pos)

            check = False

            for num_tupl, tupl in enumerate(tuples):

                if pos < tupl[0]:
                    break
                gold_locations = tupl[1]
                check = True

            if check:
                input_ids = torch.LongTensor([tokenizer.encode(prompt)])
                input_ids = input_ids.to(device)
                encoder_outputs = model.model.encoder(input_ids=input_ids, memory_states=all_memory_states[i], attention_mask=None)
                #memory_states = encoder_outputs.memory_states

                outputs = model.generate(
                    encoder_outputs=encoder_outputs,
                    decoder_start_token_id=tokenizer.bos_token_id,
                    max_length=64,
                    num_beams=1,
                    do_sample=False,
                    return_dict_in_generate=True,
                )

                out = tokenizer.decode(outputs.sequences[0])
                match1, match2 = exactly_or_fuzzily_matched(out, gold_locations)
# the old man
# 0
# 2143
# the pewter soldier
# 0
# 2131
# the clever man
# 0
# 2143
# the wife
# 0
# 2146
# 1
# the little boy
# 2200
# 4246
# the man who went on errands
# 2200
# 4232
# the old man
# 2200
# 4246
# the pewter soldier
# 2200
# 4238
# the clever man
# 2200
# 4246
# the wife
# 2200
# 4254
# 2
# the little boy
# 4320
# 6111
# the man who went on errands
# 4320
# 6095
# the old man
# 4320
# 6111
# the pewter soldier
# 4320
# 6104
# the clever man
# 4320
# 6111
# the wife
# 4320
# 6117
# 3
# the little boy
# 6184
# 8048
# the man who went on errands
# 6184
# 8036
# the old man
# 6184
# 8048
# the pewter soldier
# 6184
# 8039
# the clever man
# 6184
# 8048
# the wife
# 6184
# 8049
# 4
# the little boy
# 8101
# 10145
# the man who went on errands
# 8101
# 10126
# the old man
# 8101
# 10145
# the pewter soldier
# 8101
# 10134
# the clever man
# 8101
# 10145
# the wife
# 8101
# 10147
# 5
# the little boy
# 10208
# 12088
# the man who went on errands
# 10208
# 12073
# the old man
# 10208
# 12088
# the pewter soldier
# 10208
# 12080
# the clever man
# 10208
# 12088
# the wife
# 10208
# 12091
# 6
# the little boy
# 12148
# 14261
# the man who went on errands
# 12148
# 14245
# the old man
# 12148
# 14261
# the pewter soldier
# 12148
# 14251
# the clever man
# 12148
# 14261
# the wife
# 12148
# 14268
# 7
# the little boy
# 14340
# 15872
# the man who went on errands
# 14340
# 15872
# the old man
# 14340
# 15872
# the pewter soldier
# 14340
# 15872
# the clever man
# 14340
# 15872
# the wife
# 14340
# 15872

# %%
for result_object in all_result_objects[version]:
    print(result_object.model_out)
# Out:
# <s>.
# The old white snails were the first persons of distinction in the world, that they knew; the forest was planted for their sake, and the manor-house was there that they might be boiled and laid
# In the story above, the current location of two old snails is the manor</s>
# <s>. “Or the burdocks have grown up over it, so that they cannot come out. There need not, however, be any haste about that; but you are always in such a tremendous hurry, and the little one is beginning to be the same. Has he not been creeping up that stalk these</s>
# <s>.
# And so they went and fetched little Miss Snail. It was a whole week before she arrived; but therein was just the very best of it, for one could thus see that she was of the same species.
# And then the marriage was celebrated. Six earth-worms shone as well as</s>
# <s>.
# And so they went and fetched little Miss Snail. It was a whole week before she arrived; but therein was just the very best of it, for one could thus see that she was of the same species.
# And then the marriage was celebrated. Six earth-worms shone as well as</s>
# <s>.
# And so they went and fetched little Miss Snail. It was a whole week before she arrived; but therein was just the very best of it, for one could thus see that she was of the same species.
# And then the marriage was celebrated. Six earth-worms shone as well as</s>
# <s>.
# And so they went and fetched little Miss Snail. It was a whole week before she arrived; but therein was just the very best of it, for one could thus see that she was of the same species.
# And then the marriage was celebrated. Six earth-worms shone as well as</s>
# <s>. The old ones crept into their shells, and never more came out. They slept; the young couple governed in the forest, and had a numerous progeny, but they were never boiled, and never came on the silver dishes; so from this they concluded that the manor-house had fallen to ruins</s>
# <s>. The manor-house had fallen to ruin, and the trees had grown up over it, and the people had no more to wish for. But the little snail had a little garden, and a little house, and a little garden, and a little garden, and a little garden, and a little</s>
# <s>. The manor-house had fallen to ruin, and the trees had grown up over it, and the gnats had grown on it, and the gnats had grown on it, and the gnats had grown on it, and the gnats had grown on it, and the gnats had grown</s>
# <s>. The manor-house had fallen to ruin, and the trees had grown up over it, and the people had no more to wish for. The old ones crept into their shells, and never more came out. They slept; the young couple governed in the forest, and had a numerous progeny,</s>
# <s>. Death has been in thy chamber, and I saw him hasten away with thy little child; he goes faster than the wind, and he never
# In the story above, the current location of the poor old man is not known.
# The story is a story of a mother who is in the midst</s>
# <s>.
# But the poor mother ran out of the house and cried aloud for her child.
# Out there, in the midst of the snow, there sat a woman in long, black clothes; and she said, “Death has been in thy chamber, and I saw him hasten away with thy little</s>
# <s>. Death has been in thy chamber, and I saw him hasten away with thy little child; he goes faster than the wind, and he never brings
# In the story above, the current location of the little child is not known.
# The story is a story of a mother who is in the midst</s>
# <s>. Death has been in thy chamber, and I saw him hasten away with thy little child; he goes faster than the wind, and he never brings back what
# In the story above, the current location of Death is the house of the mother.
# The mother is a woman who has been in the</s>
# <s>.
# In the story above, the current location of the woman in black clothes is not known.
# The story of the mother and her child is told in the following form.
# The mother is a woman who has been in a terrible accident, and has been left with a child. She has been left</s>
# <s>. Then she lay down to drink up the lake, and that was an impossibility for a
# In the story above, the current location of the poor old man is not known.
# The mother was a woman, and the old man was a man.
# The mother was a woman, and the old man</s>
# <s>. Then she lay down to drink up the lake, and that was an impossibility for a human being
# In the story above, the current location of the mother is the same as the location of the mother in the story above.
# The mother is a woman who has lost her child.
# The mother is</s>
# <s>. Then she lay down to drink up the lake, and that was an impossibility for a human
# In the story above, the current location of the little child is not known.
# The mother was a woman, and the child was a boy.
# The mother was a woman, and the child was a</s>
# <s>. Then she lay down to drink up the lake, and that was an impossibility for a human being,
# In the story above, the current location of Death is the same as the location of the mother.
# The mother was a woman, and the mother was a man.
# The mother was a woman</s>
# <s>. Then she lay down to drink up the lake, and that was an impossibility for
# In the story above, the current location of the woman in black clothes is the same as the location of the woman in the story above.
# The woman in the story above is the same as the location of the woman</s>
# <s>. Then she lay down to drink up the lake, and that was an impossibility for a
# In the story above, the current location of the thorn-bush is the same as the location of the mother.
# The mother was a woman who had lost her child, and was in a state of despair.</s>
# <s>.”
# “Nay, I have nothing to do there!” said the woman. “But you can give me your long black hair; you know yourself that it is fine, and that I like! You shall have my white hair instead, and that's always something!�</s>
# <s>.”
# “Nay, I have nothing to do there!” said the woman. “But you can give me your long black hair; you know yourself that it is fine, and that I like! You shall have my white hair instead, and that's always something!�</s>
# <s>.”
# “Nay, I have nothing to do there!” said the woman. “But you can give me your long black hair; you know yourself that it is fine, and that I like! You shall have my white hair instead, and that's always something!�</s>
# <s>.”
# “Nay, I have nothing to do there!” said the woman. “But you can give me your long black hair; you know yourself that it is fine, and that I like! You shall have my white hair instead, and that's always something!�</s>
# <s>.”
# “Nay, I have nothing to do there!” said the woman. “But you can give me your long black hair; you know yourself that it is fine, and that I like! You shall have my white hair instead, and that's always something!�</s>
# <s>.”
# “Nay, I have nothing to do there!” said the woman. “But you can give me your long black hair; you know yourself that it is fine, and that I like! You shall have my white hair instead, and that's always something!�</s>
# <s>.
# “But OUR LORD can!” said she.
# “I only
# In the story above, the current location of the poor old man is in the North of England.
# The story is a very sad one, and the poor old woman is very sad.
# The story is</s>
# <s>.
# “But OUR LORD can!” said she.
# “I only do His
# In the story above, the current location of the mother is in the north of England.
# The mother is a blind woman, and she is a mother to a child.
# The mother is a</s>
# <s>.
# “But OUR LORD can!” said she.
# “I only do
# In the story above, the current location of the little child is not known.
# The story is a very sad one, and the mother is very sad.
# The story is a very sad one,</s>
# <s>.
# “But OUR LORD can!” said she.
# “I only do His bidding
# In the story above, the current location of Death is in the North of England.
# The story is a very sad one, and I am sure that the reader will find it very difficult to</s>
# <s>.
# “But OUR LORD can!” said she.
# “I
# In the story above, the current location of the woman in black clothes is the same as the location of the woman in black clothes in the story above.
# The woman in black clothes is the same as the woman</s>
# <s>.
# “But OUR LORD can!” said she.
# “I only
# In the story above, the current location of the thorn-bush is in the town of St. John's, in the county of Northumberland.
# The thorn-bush is a very old and beautiful</s>
# <s>.
# “But OUR LORD can!” said she.
# “I only do
# In the story above, the current location of the old woman is in the village of St. John, in the province of the same name.
# The old woman is a woman of the village of St</s>
# <s>.
# “I am a mother,” said she.
# “And thou hast not come quicker than I?” said Death.
# “I have come,” said she.
# “And thou hast not come quicker than I?” said Death.
# �</s>
# <s>. Take it into God's kingdom! Forget my tears, forget my prayers, and all that I have done!”
# “I do not understand thee!�
# In the story above, the current location of the mother is in the north of England.
# The mother is in the north of</s>
# <s>.
# “I do not understand thee!
# In the story above, the current location of the little child is not known.
# The mother is not yet dead.
# The mother is not yet dead.
# The mother is not yet dead.
# The mother is not yet dead.
# The mother</s>
# <s>. Take it into God's kingdom! Forget my tears, forget my prayers, and all that I have done!”
# “I do not understand thee!”
# In the story above, the current location of Death is the lake of the dead.
# The mother's child was a child</s>
# <s>. Take it into God's kingdom! Forget my tears, forget my prayers, and all that I have done!”
# “I do not understand
# In the story above, the current location of the woman in black clothes is the same as the location of the woman in black clothes in the story</s>
# <s>.
# “I am a mother,” said she.
# “And thou hast not come quicker than I?” said Death.
# “I have come,” said she.
# “And thou hast not come quicker than I?” said Death.
# �</s>
# <s>.
# “I do not understand thee!
# In the story above, the current location of the old woman is in the town of the same name.
# The story is told in the first person, and the mother is the one who is in the first person.
# The mother is the one who</s>
# <s>.”
#
# And Death took her child and went with it into the unknown land.
#
#
# In the story above, the current location of the poor old man is</s>
# <s>.”
#
# And Death took her child and went with it into the unknown land.
#
#
# In the story above, the current location of the mother is</s>
# <s>.”
#
# And Death took her child and went with it into the unknown land.
#
#
# In the story above, the current location of the little child is</s>
# <s>.”
#
# And Death took her child and went with it into the unknown land.
#
#
# In the story above, the current location of Death is</s>
# <s>.”
#
# “And thou hast not heard me,” said the mother.
#
# “And thou hast not heard me,” said Death.
#
# “And thou hast not heard me,” said the mother.
#
# “And thou hast not heard</s>
# <s>.”
#
# And Death took her child and went with it into the unknown land.
#
#
# In the story above, the current location of the thorn-bush is</s>
# <s>.”
#
# “And thou hast not heard me,” said the old woman.
#
# “And thou hast not heard me,” said the old woman.
#
# “And thou hast not heard me,” said the old woman.
#
# “And</s>
# <s>.
# “Don't come so near me,” said the garter: “I am not accustomed to it.”
# “Prude!” exclaimed the collar; and then it was taken out of the washing-tub. It was starched, hung over the back</s>
# <s>.
# “Don't come so near me,” said the garter: “I am not accustomed to it.”
# “Prude!” exclaimed the collar; and then it was taken out of the washing-tub. It was starched, hung over the back</s>
# <s>.
# “Don't come so near me,” said the garter: “I am not accustomed to it.”
# “Prude!” exclaimed the collar; and then it was taken out of the washing-tub. It was starched, hung over the back</s>
# <s>.
# “Don't come so near me, I beg of you!” said the collar. “You look so much like those men-folks.”
# “I am also a fine gentleman,” said the collar. “I have a bootjack and a</s>
# <s>.
# “Don't come so near me, I beg of you!” said the collar. “You look so much like those men-folks.”
# “I am also a fine gentleman,” said the collar. “I have a bootjack and a</s>
# <s>.
# “Don't come so near me,” said the garter: “I am not accustomed to it.”
# “Oh!” said the collar. “You look so much like those men-folks.”
# “I am also a</s>
# <s>.
# “Don't come so near me, I beg of you!” said the garter. “You look so much like those men-folks.”
# “I am also a fine gentleman,” said the collar. “I have a bootjack and</s>
# <s>.
# “Don't come so near me, I beg of you!” said the collar. “You look so much like those men-folks.”
# “I am also a fine gentleman,” said the collar. “I have a bootjack and a</s>
# <s>.
#
#
# In the story above, the current location of the false collar is the rag chest at the paper mill.
#
# The collar was made into a false collar, and then into a false collar, and then into a false collar, and then into a false collar, and then into a false</s>
# <s>.
#
#
# In the story above, the current location of the garter is the garter-box.
#
# The collar is now in the garter-box.
#
# The garter-box is now in the garter-box.
#
# The collar is now in the garter</s>
# <s>.
#
#
# In the story above, the current location of the warm box-iron is the same as that of the collar.
#
#
# The collar is now in the hands of a young lady, who is very much in love with it.
#
#
# The collar is now in the hands of</s>
# <s>.
#
#
# In the story above, the current location of the box-iron is the same as that of the collar.
#
#
# The collar is now in the hands of a young lady, who is very much in love with it.
#
#
# The collar is now in the hands of a</s>
# <s>.
#
#
# In the story above, the current location of the large company of rags is the rag chest at the paper mill; but the collar is still in the same place, and is still a very fine collar.
#
#  “Don't come so near me, I am not accustomed to it</s>
# <s>. Oh! a match might afford her a world of comfort, if she only dared take a single one out of the bundle,
# In the story above, the current location of the poor little girl is unknown.
# The story is a very sad one, and I am sure that it will be a very</s>
# <s>. Oh! a match might afford her a world of comfort, if she only dared take a single one out of the bundle, draw
# In the story above, the current location of the little girl is unknown.
# The story is a continuation of the story of the little match girl, which was told in</s>
# <s>.
# “Someone is just dead!” said the little girl; for her old grandmother, the only person who had loved her, and who was now no more, had told her, that when a star falls, a soul ascends to God.
# She drew another match against the wall:</s>
# <s>.
# “Someone is just dead!” said the little girl; for her old grandmother, the only person who had loved her, and who was now no more, had told her, that when a star falls, a soul ascends to God.
# She drew another match against the wall:</s>
# <s>.
# “Someone is just dead!” said the little girl; for her old grandmother, the only person who had loved her, and who was now no more, had told her, that when a star falls, a soul ascends to God.
# She drew another match against the wall:</s>
# <s>. Stiff and stark sat the child there with her matches, of which one bundle had been burnt. “She wanted to warm herself,” people said. No one had the slightest suspicion of what beautiful things she had seen; no one even dreamed of the splendor in which, with her grandmother</s>
# <s>. Stiff and stark sat the child there with her matches, of which one bundle had been burnt. “She wanted to warm herself,” people said. No one had the slightest suspicion of what beautiful things she had seen; no one even dreamed of the splendor in which, with her grandmother</s>
# <s>. Stiff and stark sat the child there with her matches, of which one bundle had been burnt. “She wanted to warm herself,” people said. No one had the slightest suspicion of what beautiful things she had seen; no one even dreamed of the splendor in which, with her grandmother</s>
# <s>. Stiff and stark sat the child there with her matches, of which one bundle had been burnt. “She wanted to warm herself,” people said. No one had the slightest suspicion of what beautiful things she had seen; no one even dreamed of the splendor in which, with her grandmother</s>
# <s>. Stiff and stark sat the child there with her matches, of which one bundle had been burnt. “She wanted to warm herself,” people said. No one had the slightest suspicion of what beautiful things she had seen; no one even dreamed of the splendor in which, with her grandmother</s>
# <s>.
# In the story above, the current location of Tuk is not known.
# The story is a very good one, and I am glad to have it.
# I have been reading it, and I am glad to have it.
# I have been reading it, and I am glad to have</s>
# <s>.
# In the story above, the current location of Augusta is not known.
# The story is a very good one, and I am sure you will find it very interesting.
# I have been thinking of this story, and I think it is a very good one.
# I have been thinking of this</s>
# <s>.
# In the story above, the current location of the mother is not known.
# The mother is not known.
# The mother is not known.
# <s>.
# And she went to the parsonage, and begged that they would take her into service; she would be very industrious, she said, and would do everything she could; she did not care about the wages, only she wished to have a home, and be with good people. And the</s>
# <s>.
#
# The angel was a man, and he was a very good man. He was a very good man, and he was a very good man. He was a very good man, and he was a very good man.
#
# The angel was a man, and he was a very good man</s>
# <s>.
# And she went to the parsonage, and begged that they would take her into service; she would be very industrious, she said, and would do everything she could; she did not care about the wages, only she wished to have a home, and be with good people. And the</s>
# <s>.
# “It was through mercy!” she said.
# And the organ pealed, and the children's voices in the choir sounded so sweet and soft! The clear sunshine streamed so warmly through the window into the pew where Karen sat! Her heart was so full of sunshine, peace</s>
# <s>.
# “It was through mercy!” she said.
# And the organ pealed, and the children's voices in the choir sounded so sweet and soft! The clear sunshine streamed so warmly through the window into the pew where Karen sat! Her heart was so full of sunshine, peace</s>
# <s>.
# “It was through mercy!” she said.
# And the organ pealed, and the children's voices in the choir sounded so sweet and soft! The clear sunshine streamed so warmly through the window into the pew where Karen sat! Her heart was so full of sunshine, peace</s>
# <s>.
# “It was through mercy!” she said.
# And the organ pealed, and the children's voices in the choir sounded so sweet and soft! The clear sunshine streamed so warmly through the window into the pew where Karen sat! Her heart was so full of sunshine, peace</s>
# <s>.
# “It was through mercy!” she said.
# And the organ pealed, and the children's voices in the choir sounded so sweet and soft! The clear sunshine streamed so warmly through the window into the pew where Karen sat! Her heart was so full of sunshine, peace</s>
# <s>.
# “It was through mercy!” she said.
# And the organ pealed, and the children's voices in the choir sounded so sweet and soft! The clear sunshine streamed so warmly through the window into the pew where Karen sat! Her heart was so full of sunshine, peace</s>
# <s>.
# “It was through mercy!” she said.
# And the organ pealed, and the children's voices in the choir sounded so sweet and soft! The clear sunshine streamed so warmly through the window into the pew where Karen sat! Her heart was so full of sunshine, peace</s>
# <s>.
# “It was through mercy!” she said.
# And the organ pealed, and the children's voices in the choir sounded so sweet and soft! The clear sunshine streamed so warmly through the window into the pew where Karen sat! Her heart was so full of sunshine, peace</s>
# <s>.
# “It was through mercy!” she said.
# And the organ pealed, and the children's voices in the choir sounded so sweet and soft! The clear sunshine streamed so warmly through the window into the pew where Karen sat! Her heart was so full of sunshine, peace</s>
# <s>.
# “It was through mercy!” she said.
# And the organ pealed, and the children's voices in the choir sounded so sweet and soft! The clear sunshine streamed so warmly through the window into the pew where Karen sat! Her heart was so full of sunshine, peace</s>
# <s>.
# “I should like to know how the weavers are getting on with my cloth,”  said the Emperor to himself, after some little time had elapsed; he was, however, rather embarrassed, when he remembered that a simpleton, or one unfit for his office, would be unable</s>
# <s>. “This pattern, and the colors, yes, I will tell the Emperor without delay, how very beautiful I think them.”
# “We shall be much obliged to you,” said the impostors, and then they named the different colors and described the pattern of the pretended</s>
# <s>. “This pattern, and the colors, yes, I will tell the Emperor without delay, how very beautiful I think them.”
# “We shall be much obliged to you,” said the impostors, and then they named the different colors and described the pattern of the pretended</s>
# <s>. “This pattern, and the colors, yes, I will tell the Emperor without delay, how very beautiful I think them.”
# “We shall be much obliged to you,” said the impostors, and then they named the different colors and described the pattern of the pretended</s>
# <s>. “If your Majesty will only be pleased to look at it! What a splendid design! What glorious colors!” and at the same time they pointed to the empty frames; for they imagined that everyone else could see this exquisite piece of workmanship.
# “How is this?”</s>
# <s>. “If your Majesty will only be pleased to look at it! What a splendid design! What glorious colors!” and at the same time they pointed to the empty frames; for they imagined that everyone else could see this exquisite piece of workmanship.
# “How is this?”</s>
# <s>. “If your Majesty will only be pleased to look at it! What a splendid design! What glorious colors!” and at the same time they pointed to the empty frames; for they imagined that everyone else could see this exquisite piece of workmanship.
# “How is this?”</s>
# <s>. “If your Majesty will only be pleased to look at it! What a splendid design! What glorious colors!” and at the same time they pointed to the empty frames; for they imagined that everyone else could see this exquisite piece of workmanship.
# “How is this?”</s>
# <s>. “If your Majesty will only be pleased to look at it! What a splendid design! What glorious colors!” and at the same time they pointed to the empty frames; for they imagined that everyone else could see this exquisite piece of workmanship.
# “How is this?”</s>
# <s>. “If your Majesty will only be pleased to look at it! What a splendid design! What glorious colors!” and at the same time they pointed to the empty frames; for they imagined that everyone else could see this exquisite piece of workmanship.
# “How is this?”</s>
# <s>.” said all the courtiers, although not one of them could see anything of this exquisite manufacture.
# “If your Imperial Majesty will be graciously pleased to take off your clothes, we will fit on the new suit, in front of the looking glass.”
# The Emperor was accordingly</s>
# <s>.” said all the courtiers, although not one of them could see anything of this exquisite manufacture.
# “If your Imperial Majesty will be graciously pleased to take off your clothes, we will fit on the new suit, in front of the looking glass.”
# The Emperor was accordingly</s>
# <s>.” said all the courtiers, although not one of them could see anything of this exquisite manufacture.
# “If your Imperial Majesty will be graciously pleased to take off your clothes, we will fit on the new suit, in front of the looking glass.”
# The Emperor was accordingly</s>
# <s>.” said all the courtiers, although not one of them could see anything of this exquisite manufacture.
# “If your Imperial Majesty will be graciously pleased to take off your clothes, we will fit on the new suit, in front of the looking glass.”
# The Emperor was accordingly</s>
# <s>.” said all the courtiers, although not one of them could see anything of this exquisite manufacture.
# “If your Imperial Majesty will be graciously pleased to take off your clothes, we will fit on the new suit, in front of the looking glass.”
# The Emperor was accordingly</s>
# <s>.” said all the courtiers, although not one of them could see anything of this exquisite manufacture.
# “If your Imperial Majesty will be graciously pleased to take off your clothes, we will fit on the new suit, in front of the looking glass.”
# The Emperor was accordingly</s>
# <s>.” said all the courtiers, although not one of them could see anything of this exquisite manufacture.
# “If your Imperial Majesty will be graciously pleased to take off your clothes, we will fit on the new suit, in front of the looking glass.”
# The Emperor was accordingly</s>
# <s>. And the lords of the bedchamber took greater pains than ever, to appear holding up a train, although, in reality, there was no train to hold.
#
#
# In the story above, the current location of the weavers is the same as the one in the story.
# The Emperor</s>
# <s>. And the lords of the bedchamber took greater pains than ever, to appear holding up a train, although, in reality, there was no train to hold.
#
#
# In the story above, the current location of the old minister is the palace of the Emperor.
# The Emperor was very pleased</s>
# <s>. And the lords of the bedchamber took greater pains than ever, to appear holding up a train, although, in reality, there was no train to hold.
#
#
# In the story above, the current location of the knaves is the same as the one in the story above.
# The</s>
# <s>. And the lords of the bedchamber took greater pains than ever, to appear holding up a train, although, in reality, there was no train to hold.
#
#
# In the story above, the current location of the officer of the court is the palace of the Emperor.
# The Emperor was</s>
# <s>. And the lords of the bedchamber took greater pains than ever, to appear holding up a train, although, in reality, there was no train to hold.
#
#
# In the story above, the current location of the officers of the court is the palace of the Emperor.
# The Emperor was</s>
# <s>. And the lords of the bedchamber took greater pains than ever, to appear holding up a train, although, in reality, there was no train to hold.
#
#
# In the story above, the current location of the Emperor is the palace of the King of the Romans.
# The Emperor was</s>
# <s>. And the lords of the bedchamber took greater pains than ever, to appear holding up a train, although, in reality, there was no train to hold.
#
#
# In the story above, the current location of the rogues is the same as the one in the story above.
# The</s>
# <s>. And the lords of the bedchamber took greater pains than ever, to appear holding up a train, although, in reality, there was no train to hold.
#
#
# In the story above, the current location of the chief master of the ceremonies is the palace of the Emperor.
# The Emperor</s>
# <s>. And the lords of the bedchamber took greater pains than ever, to appear holding up a train, although, in reality, there was no train to hold.
#
#
# In the story above, the current location of the lords of the bedchamber is not known.
# The Emperor was now</s>
# <s>. And the lords of the bedchamber took greater pains than ever, to appear holding up a train, although, in reality, there was no train to hold.
#
#
# In the story above, the current location of the child is the palace of the Emperor.
# The Emperor was now in the</s>
# <s>. And the lords of the bedchamber took greater pains than ever, to appear holding up a train, although, in reality, there was no train to hold.
#
#
# In the story above, the current location of the child's father is not known.
# The Emperor was now in the midst</s>
# <s>.
# “Superbe! Charmant!” exclaimed the ladies; for they all
# In the story above, the current location of the princess is not known.
# The Princess is now in the palace of the Emperor, and is playing at “Visiting,” with the ladies of</s>
# <s>.
# “Superbe! Charmant!” exclaimed the ladies; for they all
# In the story above, the current location of the ladies is not known.
# The Princess was very happy to see the rose and the nightingale; and she was very happy to see the rose tree,</s>
# <s>.
# “Superbe! Charmant!” exclaimed the ladies; for they all
# In the story above, the current location of the emperor is in the East.
# The story is a little different from the one above, in that the Princess is a little girl, and the Emperor is a</s>
# <s>.
# “Why there is my piece,” said the Princess. �
# In the story above, the current location of the princess is the palace of the Emperor.
# The Princess was a very pretty girl, and she was very pretty. She was very pretty, and she was very pretty.</s>
# “I saw you all over there at home so distinctly, as if you really were here; it was again that Sunday morning; all you children stood before the table and sung your Psalms, as you do every morning. You stood devoutly with folded hands; and father and mother were just</s>
# <s>.
# In the evening there was a hearse seen before the door, and he was borne into it in his coffin:
# In the story above, the current location of the little boy is the old house.
# The old man was dead, and the little boy was gone.
# The old man was</s>
# <s>. The windows were quite frozen, the little boy was obliged to sit and breathe on them to get a peep-hole over to the old house, and there the snow had been blown into all the carved work and inscriptions; it lay quite up over the steps, just as if there was no one</s>
# <s>. The windows were quite frozen, the little boy was obliged to sit and breathe on them to get a peep-hole over to the old house, and there the snow had been blown into all the carved work and inscriptions; it lay quite up over the steps, just as if there was no one</s>
# <s>. The windows were quite frozen, the little boy was obliged to sit and breathe on them to get a peep-hole over to the old house, and there the snow had been blown into all the carved work and inscriptions; it lay quite up over the steps, just as if there was no one</s>
# <s>.
# It was--yes, guess! It was the pewter soldier, he that was lost up at the old man's, and had tumbled and
# In the story above, the current location of the little boy is the house of the pewter soldier.
# The little boy is now</s>
# <s>.
# It was--yes, guess! It was the pewter soldier, he that was lost up at the old man's, and
# In the story above, the current location of the man who went on errands is the same as the location of the pewter soldier.
# The p</s>
# <s>.
# It was--yes, guess! It was the pewter soldier, he that was lost up at the old man's, and had tumbled and
# In the story above, the current location of the old man is the same as the one in the story.
# The old man is a</s>
# <s>.
# It was--yes, guess! It was the pewter soldier, he that was lost up at the old man's, and had t
# In the story above, the current location of the pewter soldier is the house of the little boy.
# The pewter soldier is now</s>
# <s>.
# It was--yes, guess! It was the pewter soldier, he that was lost up at the old man's, and had tumbled and
# In the story above, the current location of the clever man is the house of the pewter soldier.
# The pewter soldier</s>
# <s>.
# It was--yes, guess! It was the pewter soldier, he that was lost up at the old man's, and had tumbled and turned
# In the story above, the current location of the wife is the house of the pewter soldier.
# The pewter soldier</s>
# <s>.
# “How very, very lonely he must have been!” said she.
# “Very, very lonely!” said the pewter soldier. “But it is delightful not to be forgotten!”
# “Delightful!” shouted something close by</s>
# <s>.
# “How very, very lonely he must have been!” said she.
# “Very, very lonely!” said the pewter soldier. “But it is delightful not to be forgotten!”
# “Delightful!” shouted something close by</s>
# <s>. It had lost all its gilding, it looked like a piece of wet clay, but it had an opinion, and it gave it:
#    “The gilding decays,    But hog's leather stays!”
# This the pewter soldier did not</s>
# <s>. It had lost all its gilding, it looked like a piece of wet clay, but it had an opinion, and it gave it:
#    “The gilding decays,    But hog's leather stays!”
# This the pewter soldier did not</s>
# <s>.
# “How very, very lonely he must have been!” said she.
# “Very, very lonely!” said the pewter soldier. “But it is delightful not to be forgotten!”
# “Delightful!” shouted something close by</s>
# <s>. It had lost all its gilding, it looked like a piece of wet clay, but it had an opinion, and it gave it:
#    “The gilding decays,    But hog's leather stays!”
# This the pewter soldier did not</s>

# %%
self.prompt = prompt
        self.model_out = model_out
        self.gold_locations = gold_locations
        self.character = character
        self.k = k
        self.story_no = story_no
        self.query_point = query_point
        self.exact_match = exact_match
        self.fuzzy_match = fuzzy_match

# %%
def create_membart_prompt(tokenizer, version, context, character, grammatical_number, max_no_tokens=512):

    prompt = context + "\nIn the story above, the current location of " + character + " is"
    pos = len(context)
    
    if len(tokenizer.encode(prompt)) > max_no_tokens:
    
        context = tokenizer.encode(context)
        diff = len(tokenizer.encode(prompt)) - max_no_tokens
        context = context[:-diff]
        context = tokenizer.decode(context, skip_special_tokens=True)
        prompt = context + "\nIn the story above, the current location of " + character + " is"
        pos = len(context)
        
        if len(tokenizer.encode(prompt)) > max_no_tokens:
            context = tokenizer.encode(context)
            context = context[:-2]
            context = tokenizer.decode(context, skip_special_tokens=True)
            prompt = context + "\nIn the story above, the current location of " + character + " is"
            pos = len(context)

    return prompt, pos

# %%
print(all_prompt_drafts[0])
# Out:
# Story:
# THE HAPPY FAMILY
# Really, the largest green leaf in this country is a dock-leaf; if one holds it before one, it is like a whole apron, and if one holds it over one's head in rainy weather, it is almost as good as an umbrella, for it is so immensely large. The burdock never grows alone, but where there grows one there always grow several: it is a great delight, and all this delightfulness is snails' food. The great white snails which persons of quality in former times made fricassees of, ate, and said, “Hem, hem! how delicious!” for they thought it tasted so delicate--lived on dock-leaves, and therefore burdock seeds were sown.
# Now, there was an old manor-house, where they no longer ate snails, they were quite extinct; but the burdocks were not extinct, they grew and grew all over the walks and all the beds; they could not get the mastery over them--it was a whole forest of burdocks. Here and there stood an apple and a plum-tree, or else one never would have thought that it was a garden; all was burdocks, and there lived the two last venerable old snails.
# They themselves knew not how old they were, but they could remember very well that there had been many more; that they were of a family from foreign lands, and that for them and theirs the whole forest was planted. They had never been outside it, but they knew that there was still something more in the world, which was called the manor-house, and that there they were boiled, and then they became black, and were then placed on a silver dish; but what happened further they knew not; or, in fact, what it was to be boiled, and to lie on a silver dish, they could not possibly imagine; but it was said to be delightful, and particularly genteel. Neither the chafers, the toads, nor the earth-worms, whom they asked about it could give them any information--none of them had been boiled or laid on a silver dish.
# The old white snails were the first persons of distinction in the world, that they knew; the forest was planted for their sake, and the manor-house was there that they might be boiled and laid on a silver dish.
# Now they lived a very lonely and happy life;

# %%
print(story[:2138])
# Out:
# THE HAPPY FAMILY
# Really, the largest green leaf in this country is a dock-leaf; if one holds it before one, it is like a whole apron, and if one holds it over one's head in rainy weather, it is almost as good as an umbrella, for it is so immensely large. The burdock never grows alone, but where there grows one there always grow several: it is a great delight, and all this delightfulness is snails' food. The great white snails which persons of quality in former times made fricassees of, ate, and said, “Hem, hem! how delicious!” for they thought it tasted so delicate--lived on dock-leaves, and therefore burdock seeds were sown.
# Now, there was an old manor-house, where they no longer ate snails, they were quite extinct; but the burdocks were not extinct, they grew and grew all over the walks and all the beds; they could not get the mastery over them--it was a whole forest of burdocks. Here and there stood an apple and a plum-tree, or else one never would have thought that it was a garden; all was burdocks, and there lived the two last venerable old snails.
# They themselves knew not how old they were, but they could remember very well that there had been many more; that they were of a family from foreign lands, and that for them and theirs the whole forest was planted. They had never been outside it, but they knew that there was still something more in the world, which was called the manor-house, and that there they were boiled, and then they became black, and were then placed on a silver dish; but what happened further they knew not; or, in fact, what it was to be boiled, and to lie on a silver dish, they could not possibly imagine; but it was said to be delightful, and particularly genteel. Neither the chafers, the toads, nor the earth-worms, whom they asked about it could give them any information--none of them had been boiled or laid on a silver dish.
# The old white snails were the first persons of distinction in the world, that they knew; the forest was planted for their sake, and the manor-house was there that they might be boiled and laid on a silver dish.
# Now they lived a very lonely and happy life;

# %%
story[:2138] == all_prompt_drafts[0][7:]
# Out:
# True
